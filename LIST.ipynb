# %% [markdown]
# collection data type is like a container used to store multiple data items. List: its an ordered sequence, mutable collection of data, infinite length, iterable, allow duplicate members and return with square bracket.

# %%
list = ["anu","sini",6,7,8]
print(list)
# Out:
# ['anu', 'sini', 6, 7, 8]

# %% [markdown]
# nested list a list inside another list
